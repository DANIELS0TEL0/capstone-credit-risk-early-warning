# %%
import pandas as pd

df = pd.read_csv(
    r"C:\Users\bdgsg\Downloads\Capstone Project Dataset\GitHub\capstone-credit-risk-early-warning\data\processed\early_default_modeling_dataset.csv",
    parse_dates=["issue_d"]
)
